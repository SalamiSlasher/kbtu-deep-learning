# %% [markdown]
# # MLP in PyTorch

# %%
import numpy as np
import jdc
from time import time
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, TensorDataset
print(torch.__version__)
# Out:
# 2.2.0

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# Build a generic MLP model. [Stackoverflow](https://stackoverflow.com/questions/39691902/ordering-of-batch-normalization-and-dropout) suggests the following sequence of layers in a block:
#
# * linear layer
# * [batch normalization layer](https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm1d.html) (optional)
# * activation layer
# * [dropout layer](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html#dropout) (optional)

# %%
class MLP(nn.Module):
    def __init__(self, hidden_sizes: list[int], output_size=10, activation_func=nn.ReLU,
                 dropout_prob=None, use_batchnorm=False):
        super(MLP, self).__init__()
        layers = []
        for i in range(len(hidden_sizes)):
            if i == 0:
                layers.append(nn.LazyLinear(hidden_sizes[0]))
            else:
                layers.append(nn.Linear(hidden_sizes[i-1], hidden_sizes[i]))

            if use_batchnorm:
                layers.append(nn.BatchNorm1d(hidden_sizes[i]))
            
            layers.append(activation_func())

            if dropout_prob is not None:
                layers.append(nn.Dropout(dropout_prob))

        layers.append(nn.Linear(hidden_sizes[-1], output_size))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# PyTorch has the whole [zoo](https://pytorch.org/docs/stable/optim.html#algorithms) of optimizers, e.g:
#
# * classical [SGD](https://pytorch.org/docs/stable/generated/torch.optim.SGD.html#torch.optim.SGD), optionally enhanced with momentum and NAG
#
# * one of the most popular optimizers — [Adam](https://pytorch.org/docs/stable/generated/torch.optim.Adam.html#torch.optim.Adam)
#
# Feel free to experiment with any optimizer you want. The next method sets the optimizer which will be used while training:

# %%
# %%add_to MLP
# def add_optimizer(self, optim_func, param_dict=dict()):
#     self.optimizer = optim_func(self.model.parameters(), **param_dict)

# %% [markdown]
# The next method is used to calculate validation and test accuracy:

# %%
# %%add_to MLP
# def accuracy(self, dataloader):
#     self.model.eval()
#     correct = 0
#     total = 0
#     for images, labels in dataloader:
#         images = images.view(-1, 28 * 28)
#         outputs = model(images)
#         _, predicted = torch.max(outputs, 1)
#         correct += (predicted == labels).sum().item()
#         total += labels.size(0)
#     return correct / total

# %% [markdown]
# Add `train` method to our class:

# %%
# %%add_to MLP
# def train(self, num_epochs, batch_size):
#     transform = transforms.Compose([transforms.ToTensor()])
#
#     # Load the MNIST dataset
#     train_dataset = datasets.MNIST(root='./mnist', train=True, transform=transform, download=True)
#     test_dataset = datasets.MNIST(root='./mnist', train=False, transform=transform, download=True)
#
#     # Split into train and validation
#     train_subset, val_subset = torch.utils.data.random_split(train_dataset, [50000, 10000])
#
#     # Set dataloaders
#     train_loader = DataLoader(dataset=train_subset, batch_size=batch_size, shuffle=True)
#     val_loader = DataLoader(dataset=val_subset, batch_size=batch_size, shuffle=True)
#     test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True)
#
#     # Set loss function
#     criterion = nn.CrossEntropyLoss()
#
#     # Training loop
#     # One epoch = one pass over training dataset
#     losses, train_accs, val_accs, times = [], [], [], []
#     for epoch in range(num_epochs):
#         begin = time()
#         total_correct_train = 0
#         total_samples_train = 0
#         self.model.train()
#         running_loss = 0.0
#
#         # Iterating by mini-batches
#         for i, (images, labels) in enumerate(train_loader):
#             images = images.view(-1, 28 * 28)
#
#             # Set all gradients to 0
#             self.optimizer.zero_grad()
#
#             # Forward pass
#             outputs = model(images)
#
#             # Calculate loss function
#             loss = criterion(outputs, labels)
#
#             # Backward pass
#             loss.backward()
#
#             # Gradient step
#             self.optimizer.step()
#             running_loss += loss.item()
#
#             _, predicted = torch.max(outputs, 1)
#             total_correct_train += (predicted == labels).sum().item()
#             total_samples_train += labels.size(0)
#
#             if (i+1) % (len(train_loader) // 10) == 0:
#                 print('Epoch [{}/{}], step [{}/{}],train loss: {:.4f}, train accuracy: {:.2%}'.format(
#                     epoch+1, num_epochs, i+1, len(train_loader),
#                     running_loss/(i+1), total_correct_train / total_samples_train)
#                 )
#         val_acc = self.accuracy(val_loader)
#         losses.append(running_loss/len(train_loader))
#         train_accs.append(total_correct_train / total_samples_train)
#         val_accs.append(val_acc)
#         times.append(time() - begin)
#         print(f"Validation accuracy: {val_acc:.2%}")
#         print(f"Epoch {epoch + 1} took {times[-1]:.3f} s")
#     test_acc = self.accuracy(test_loader)
#     print(f"Test accuracy: {test_acc:.2%}")
#     return losses, train_accs, val_accs, test_acc, sum(times)

# %%
hidden_sizes = [384, 192]
model = MLP(hidden_sizes, activation_func=nn.Tanh, use_batchnorm=True)
print(model)
# Out:
# MLP(
#   (model): Sequential(
#     (0): LazyLinear(in_features=0, out_features=384, bias=True)
#     (1): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Tanh()
#     (3): Linear(in_features=384, out_features=192, bias=True)
#     (4): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): Tanh()
#     (6): Linear(in_features=192, out_features=10, bias=True)
#   )
# )

# %%
model.add_optimizer(optim.Adam)

# %%
n_epochs = 10
batch_size = 50
losses, train_accs, val_accs, test_acc, time_elapsed = model.train(n_epochs, batch_size)
# Out:
# Epoch [1/10], step [100/1000],train loss: 0.0301, train accuracy: 99.00%
# Epoch [1/10], step [200/1000],train loss: 0.0359, train accuracy: 98.81%
# Epoch [1/10], step [300/1000],train loss: 0.0404, train accuracy: 98.71%
# Epoch [1/10], step [400/1000],train loss: 0.0411, train accuracy: 98.67%
# Epoch [1/10], step [500/1000],train loss: 0.0425, train accuracy: 98.61%
# Epoch [1/10], step [600/1000],train loss: 0.0423, train accuracy: 98.60%
# Epoch [1/10], step [700/1000],train loss: 0.0409, train accuracy: 98.68%
# Epoch [1/10], step [800/1000],train loss: 0.0397, train accuracy: 98.71%
# Epoch [1/10], step [900/1000],train loss: 0.0396, train accuracy: 98.73%
# Epoch [1/10], step [1000/1000],train loss: 0.0391, train accuracy: 98.74%
# Validation accuracy: 99.21%
# Epoch 1 took 5.005 s
# Epoch [2/10], step [100/1000],train loss: 0.0173, train accuracy: 99.44%
# Epoch [2/10], step [200/1000],train loss: 0.0189, train accuracy: 99.32%
# Epoch [2/10], step [300/1000],train loss: 0.0188, train accuracy: 99.34%
# Epoch [2/10], step [400/1000],train loss: 0.0201, train accuracy: 99.31%
# Epoch [2/10], step [500/1000],train loss: 0.0214, train accuracy: 99.28%
# Epoch [2/10], step [600/1000],train loss: 0.0213, train accuracy: 99.29%
# Epoch [2/10], step [700/1000],train loss: 0.0216, train accuracy: 99.29%
# Epoch [2/10], step [800/1000],train loss: 0.0218, train accuracy: 99.28%
# Epoch [2/10], step [900/1000],train loss: 0.0222, train accuracy: 99.26%
# Epoch [2/10], step [1000/1000],train loss: 0.0232, train accuracy: 99.21%
# Validation accuracy: 98.94%
# Epoch 2 took 4.804 s
# Epoch [3/10], step [100/1000],train loss: 0.0174, train accuracy: 99.54%
# Epoch [3/10], step [200/1000],train loss: 0.0198, train accuracy: 99.46%
# Epoch [3/10], step [300/1000],train loss: 0.0188, train accuracy: 99.47%
# Epoch [3/10], step [400/1000],train loss: 0.0182, train accuracy: 99.45%
# Epoch [3/10], step [500/1000],train loss: 0.0195, train accuracy: 99.41%
# Epoch [3/10], step [600/1000],train loss: 0.0195, train accuracy: 99.42%
# Epoch [3/10], step [700/1000],train loss: 0.0194, train accuracy: 99.42%
# Epoch [3/10], step [800/1000],train loss: 0.0190, train accuracy: 99.43%
# Epoch [3/10], step [900/1000],train loss: 0.0195, train accuracy: 99.39%
# Epoch [3/10], step [1000/1000],train loss: 0.0210, train accuracy: 99.32%
# Validation accuracy: 99.25%
# Epoch 3 took 4.841 s
# Epoch [4/10], step [100/1000],train loss: 0.0140, train accuracy: 99.52%
# Epoch [4/10], step [200/1000],train loss: 0.0163, train accuracy: 99.44%
# Epoch [4/10], step [300/1000],train loss: 0.0171, train accuracy: 99.44%
# Epoch [4/10], step [400/1000],train loss: 0.0170, train accuracy: 99.45%
# Epoch [4/10], step [500/1000],train loss: 0.0165, train accuracy: 99.48%
# Epoch [4/10], step [600/1000],train loss: 0.0167, train accuracy: 99.46%
# Epoch [4/10], step [700/1000],train loss: 0.0176, train accuracy: 99.42%
# Epoch [4/10], step [800/1000],train loss: 0.0182, train accuracy: 99.38%
# Epoch [4/10], step [900/1000],train loss: 0.0182, train accuracy: 99.37%
# Epoch [4/10], step [1000/1000],train loss: 0.0180, train accuracy: 99.38%
# Validation accuracy: 99.08%
# Epoch 4 took 4.797 s
# Epoch [5/10], step [100/1000],train loss: 0.0091, train accuracy: 99.68%
# Epoch [5/10], step [200/1000],train loss: 0.0133, train accuracy: 99.58%
# Epoch [5/10], step [300/1000],train loss: 0.0133, train accuracy: 99.57%
# Epoch [5/10], step [400/1000],train loss: 0.0128, train accuracy: 99.58%
# Epoch [5/10], step [500/1000],train loss: 0.0123, train accuracy: 99.58%
# Epoch [5/10], step [600/1000],train loss: 0.0127, train accuracy: 99.56%
# Epoch [5/10], step [700/1000],train loss: 0.0129, train accuracy: 99.56%
# Epoch [5/10], step [800/1000],train loss: 0.0139, train accuracy: 99.53%
# Epoch [5/10], step [900/1000],train loss: 0.0142, train accuracy: 99.52%
# Epoch [5/10], step [1000/1000],train loss: 0.0151, train accuracy: 99.49%
# Validation accuracy: 99.20%
# Epoch 5 took 4.797 s
# Epoch [6/10], step [100/1000],train loss: 0.0155, train accuracy: 99.48%
# Epoch [6/10], step [200/1000],train loss: 0.0163, train accuracy: 99.48%
# Epoch [6/10], step [300/1000],train loss: 0.0145, train accuracy: 99.55%
# Epoch [6/10], step [400/1000],train loss: 0.0132, train accuracy: 99.59%
# Epoch [6/10], step [500/1000],train loss: 0.0134, train accuracy: 99.58%
# Epoch [6/10], step [600/1000],train loss: 0.0132, train accuracy: 99.59%
# Epoch [6/10], step [700/1000],train loss: 0.0143, train accuracy: 99.55%
# Epoch [6/10], step [800/1000],train loss: 0.0143, train accuracy: 99.54%
# Epoch [6/10], step [900/1000],train loss: 0.0141, train accuracy: 99.55%
# Epoch [6/10], step [1000/1000],train loss: 0.0143, train accuracy: 99.54%
# Validation accuracy: 99.05%
# Epoch 6 took 4.822 s
# Epoch [7/10], step [100/1000],train loss: 0.0138, train accuracy: 99.56%
# Epoch [7/10], step [200/1000],train loss: 0.0122, train accuracy: 99.59%
# Epoch [7/10], step [300/1000],train loss: 0.0149, train accuracy: 99.45%
# Epoch [7/10], step [400/1000],train loss: 0.0152, train accuracy: 99.42%
# Epoch [7/10], step [500/1000],train loss: 0.0144, train accuracy: 99.47%
# Epoch [7/10], step [600/1000],train loss: 0.0143, train accuracy: 99.46%
# Epoch [7/10], step [700/1000],train loss: 0.0135, train accuracy: 99.50%
# Epoch [7/10], step [800/1000],train loss: 0.0132, train accuracy: 99.52%
# Epoch [7/10], step [900/1000],train loss: 0.0135, train accuracy: 99.52%
# Epoch [7/10], step [1000/1000],train loss: 0.0132, train accuracy: 99.53%
# Validation accuracy: 99.12%
# Epoch 7 took 4.835 s
# Epoch [8/10], step [100/1000],train loss: 0.0188, train accuracy: 99.32%
# Epoch [8/10], step [200/1000],train loss: 0.0136, train accuracy: 99.51%
# Epoch [8/10], step [300/1000],train loss: 0.0147, train accuracy: 99.46%
# Epoch [8/10], step [400/1000],train loss: 0.0140, train accuracy: 99.49%
# Epoch [8/10], step [500/1000],train loss: 0.0138, train accuracy: 99.50%
# Epoch [8/10], step [600/1000],train loss: 0.0135, train accuracy: 99.50%
# Epoch [8/10], step [700/1000],train loss: 0.0130, train accuracy: 99.53%
# Epoch [8/10], step [800/1000],train loss: 0.0131, train accuracy: 99.54%
# Epoch [8/10], step [900/1000],train loss: 0.0132, train accuracy: 99.54%
# Epoch [8/10], step [1000/1000],train loss: 0.0136, train accuracy: 99.53%
# Validation accuracy: 98.95%
# Epoch 8 took 4.800 s
# Epoch [9/10], step [100/1000],train loss: 0.0094, train accuracy: 99.70%
# Epoch [9/10], step [200/1000],train loss: 0.0088, train accuracy: 99.70%
# Epoch [9/10], step [300/1000],train loss: 0.0082, train accuracy: 99.73%
# Epoch [9/10], step [400/1000],train loss: 0.0089, train accuracy: 99.69%
# Epoch [9/10], step [500/1000],train loss: 0.0102, train accuracy: 99.66%
# Epoch [9/10], step [600/1000],train loss: 0.0113, train accuracy: 99.62%
# Epoch [9/10], step [700/1000],train loss: 0.0111, train accuracy: 99.63%
# Epoch [9/10], step [800/1000],train loss: 0.0112, train accuracy: 99.63%
# Epoch [9/10], step [900/1000],train loss: 0.0113, train accuracy: 99.62%
# Epoch [9/10], step [1000/1000],train loss: 0.0112, train accuracy: 99.64%
# Validation accuracy: 98.99%
# Epoch 9 took 4.793 s
# Epoch [10/10], step [100/1000],train loss: 0.0077, train accuracy: 99.70%
# Epoch [10/10], step [200/1000],train loss: 0.0102, train accuracy: 99.63%
# Epoch [10/10], step [300/1000],train loss: 0.0110, train accuracy: 99.63%
# Epoch [10/10], step [400/1000],train loss: 0.0108, train accuracy: 99.62%
# Epoch [10/10], step [500/1000],train loss: 0.0115, train accuracy: 99.62%
# Epoch [10/10], step [600/1000],train loss: 0.0109, train accuracy: 99.64%
# Epoch [10/10], step [700/1000],train loss: 0.0107, train accuracy: 99.66%
# Epoch [10/10], step [800/1000],train loss: 0.0100, train accuracy: 99.68%
# Epoch [10/10], step [900/1000],train loss: 0.0103, train accuracy: 99.66%
# Epoch [10/10], step [1000/1000],train loss: 0.0106, train accuracy: 99.64%
# Validation accuracy: 98.80%
# Epoch 10 took 4.858 s
# Test accuracy: 97.82%

# %%
# %config InlineBackend.figure_formats = ['svg']

def plot_accuracy(optim_name, train_accs, val_accs, test_acc, time_elapsed):
    plt.plot(np.arange(1, n_epochs + 1), train_accs, lw=2, c='b', label="train")
    plt.plot(np.arange(1, n_epochs + 1), val_accs, lw=2, c='r', label="val")
    plt.xlim(1, n_epochs)
    plt.grid(ls=":")
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.title(f"NN with {len(hidden_sizes)} hidden layers and {optim_name} opt took {time_elapsed:.1f} s, test acc: {test_acc:.2%}");

# %%
plot_accuracy("SGD", train_accs, val_accs, test_acc, time_elapsed)

# %%
plot_accuracy("SGD+momentum", train_accs, val_accs, test_acc, time_elapsed)

# %%
plot_accuracy("SGD+momentum-dropout", train_accs, val_accs, test_acc, time_elapsed)

# %%
plot_accuracy("Adam+batchnorm", train_accs, val_accs, test_acc, time_elapsed)

# %% [markdown]
# DL is all about experiments. Make as many experiments with MLP on MNIST datasets and visualize your results. Things to explore:
#
# 1. Different architectures: tweak
#     * number of hidden layers
#     * sizes of hidden layers
#     * including dropout and/or batchnorm
#     * activation function
#
# 2. Tuning parameter (such as learning rate) of different optimizers: try
#     * SGD
#     * Adam
#     * RMSProp
#     * etc
#
# Do not forget to display test accuracy and training time of each model
